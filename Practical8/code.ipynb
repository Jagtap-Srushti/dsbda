# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('https://raw.githubusercontent.com/dphi-official/Datasets/master/titanic_data.csv')
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.shape
# Out:
# (891, 12)

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data.describe(include = 'object')
# Out:
#                        Name   Sex  Ticket Cabin Embarked
# count                   891   891     891   204      889
# unique                  891     2     681   147        3
# top     Dooley, Mr. Patrick  male  347082    G6        S
# freq                      1   577       7     4      644

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data['Age'] = data['Age'].fillna(np.mean(data['Age']))

# %%
data['Cabin'] = data['Cabin'].fillna(data['Cabin'].mode()[0])

# %%
data['Embarked'] = data['Embarked'].fillna(data['Embarked'].mode()[0])

# %%
data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
sns.countplot(x=data['Survived'], hue=data['Survived'], palette='Set2', legend=False)
plt.show()

# %%
sns.countplot(x=data['Pclass'], hue=data['Pclass'], palette='Set2', legend=False)
plt.show()

# %%
sns.countplot(x=data['Embarked'], hue=data['Embarked'], palette='Set2', legend =False)
plt.show()

# %%
sns.countplot(x=data['Sex'],hue=data['Sex'],palette='Set2', legend=True)
plt.show()

# %%
sns.boxplot(x=data['Age'])
plt.show()

# %%
sns.boxplot(x=data['Fare'])
plt.show()

# %%
sns.boxplot(x=data['Pclass'])
plt.show()

# %%
sns.boxplot(x=data['SibSp'])
plt.show()

# %%
sns.catplot(x='Pclass', y='Age', hue='Pclass', data=data, kind='box', palette='Set2', legend=False)

# %%
sns.catplot(x='Pclass', y ='Fare', hue='Pclass', data=data, kind = 'strip', palette='Set2',legend=False)

# %%
sns.catplot(x='Sex', y ='Fare', hue='Sex', data=data, kind = 'strip', palette='Set2', legend=False)

# %%
sns.catplot(x= 'Sex', y = 'Age',hue='Sex', data=data, kind = 'strip',palette='Set2' ,legend=False)

# %%
sns.pairplot(data)

# %%
sns.scatterplot(x = 'Fare', y = 'Pclass', hue = 'Survived', data = data)
# Out:
# <Axes: xlabel='Fare', ylabel='Pclass'>

# %%
sns.scatterplot(x = 'Survived', y = 'Fare', data = data)
# Out:
# <Axes: xlabel='Survived', ylabel='Fare'>

# %%
sns.histplot(data['Age'], kde=True)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.histplot(data['Fare'], kde=True)
# Out:
# <Axes: xlabel='Fare', ylabel='Count'>

# %%
sns.jointplot(x = "Survived", y = "Fare", kind = "scatter", data = data)

# %%
tc = data.corr(numeric_only=True)
sns.heatmap(tc, cmap="YlGnBu")
plt.title('Correlation')
# Out:
# Text(0.5, 1.0, 'Correlation')

# %%
sns.catplot(x='Pclass', y='Fare',hue='Pclass', data=data, kind='bar',palette='Set2',legend=False)
